# %%
from source.outliers_detector_utils import *
from source.outliers_detector import OutlierGridSearcher
# Out:
# 2022-03-04 16:15:42.147263: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-03-04 16:15:42.147317: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
#*** heartFailurePrediction ***#
ogsheartFailurePrediction = OutlierGridSearcher(train_func=train_model_heart)
X_train, y_train = load_data_heartFailurePrediction()
X_filtered, y_filtered = ogsheartFailurePrediction.fit(X_train, y_train, top_nums_to_remove=[0, 5, 10])
# Out:
# testing COF
# testing OCSVM
# testing KNN
# testing MCD
# testing PCA
# testing LODA
# testing COPOD
# testing ECOD
# testing SO_GAAL
# 2022-03-04 16:15:45.254750: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2022-03-04 16:15:45.266896: E tensorflow/stream_executor/cuda/cuda_driver.cc:328] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-03-04 16:15:45.266945: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (il-eyalco-lp): /proc/driver/nvidia/version does not exist
# 2022-03-04 16:15:45.267281: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-03-04 16:15:45.337801: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2022-03-04 16:15:45.338401: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2803000000 Hz
# ### OUTPUT ###
# The best score was achieved using PCA when filtering 10 outliers
#                0         5         10
# COF      0.848230  0.842655  0.842575
# OCSVM    0.848713  0.853447  0.852832
# KNN      0.848713  0.843668  0.837544
# MCD      0.851582  0.852729  0.848379
# PCA      0.851295  0.838756  0.856323
# LODA     0.848549  0.852180  0.847948
# COPOD    0.845202  0.843998  0.845885
# ECOD     0.854999  0.853700  0.845537
# SO_GAAL  0.851582  0.844524  0.847043

# %%
#*** HeartDiseaseUCI ***#
ogsHeartDiseaseUCI = OutlierGridSearcher(train_func=train_model_heart, scoring_weights=[0.4, 0.0, 0.1, 0.5])
X_train, y_train = load_data_HeartDiseaseUCI()
X_filtered, y_filtered = ogsHeartDiseaseUCI.fit(X_train, y_train)
# Out:
# testing COF
# testing OCSVM
# testing KNN
# testing MCD
# testing PCA
# testing LODA
# testing COPOD
# testing ECOD
# testing SO_GAAL
#
#
# ### OUTPUT ###
# The best score was achieved using PCA when filtering 20 outliers
#                0         5         10        20        30
# COF      0.838809  0.836714  0.836924  0.838986  0.836723
# OCSVM    0.842012  0.841157  0.840184  0.839439  0.839898
# KNN      0.838664  0.837831  0.837763  0.836980  0.840446
# MCD      0.836756  0.840891  0.839741  0.842028  0.842139
# PCA      0.835890  0.841116  0.843999  0.847245  0.846657
# LODA     0.837854  0.840273  0.838676  0.839122  0.840014
# COPOD    0.839997  0.839943  0.840974  0.841314  0.842237
# ECOD     0.835849  0.834834  0.834846  0.835659  0.835671
# SO_GAAL  0.836869  0.838197  0.838123  0.836289  0.837658

# %%
# *** Cardiotocography ***#
ogsCardiotocography = OutlierGridSearcher(train_func=train_model_Cardiotocography)
X_train, y_train = load_data_Cardiotocography()
X_filtered, y_filtered = ogsCardiotocography.fit(X_train, y_train, top_nums_to_remove=[0, 10, 30, 50, 100, 150, 200])
# Out:
# testing COF
# testing OCSVM
# testing KNN
# testing MCD
# testing PCA
# testing LODA
# testing COPOD
# testing ECOD
# testing SO_GAAL
#
#
# ### OUTPUT ###
# The best score was achieved using COF when filtering 30 outliers
#               0         10        30        50        100       150       200
# COF      0.843972  0.836105  0.875300  0.842615  0.848635  0.834606  0.819843
# OCSVM    0.843972  0.814727  0.810552  0.794189  0.843672  0.860051  0.819843
# KNN      0.843972  0.800475  0.836930  0.871671  0.821340  0.860051  0.853786
# MCD      0.843972  0.836105  0.793765  0.849879  0.838710  0.814249  0.825065
# PCA      0.843972  0.831354  0.846523  0.840194  0.823821  0.852417  0.832898
# LODA     0.843972  0.824228  0.822542  0.828087  0.856079  0.849873  0.812010
# COPOD    0.843972  0.845606  0.824940  0.825666  0.833747  0.816794  0.856397
# ECOD     0.841608  0.838480  0.827338  0.837772  0.848635  0.806616  0.801567
# SO_GAAL  0.843972  0.795724  0.827338  0.837772  0.866005  0.814249  0.832898

# %%
#*** HousePrices ***#
ogsHousePrices = OutlierGridSearcher(train_model_house, higher_is_better=False)
X_train, y_train = load_data_house()
X_filtered, y_filtered = ogsHousePrices.fit(X_train, y_train, top_nums_to_remove=[0, 10, 20, 30])
# Out:
# testing COF
# testing OCSVM
# testing KNN
# testing MCD
# testing PCA
# testing LODA
# testing COPOD
# testing ECOD
# testing SO_GAAL
#
#
# ### OUTPUT ###
# The best score was achieved using COF when filtering 30 outliers
#                0         10        20        30
# COF      0.023315  0.019835  0.015606  0.013052
# OCSVM    0.023708  0.023572  0.045769  0.020941
# KNN      0.023262  0.016113  0.022091  0.017347
# MCD      0.023759  0.045941  0.020502  0.050294
# PCA      0.023162  0.018306  0.019130  0.019191
# LODA     0.024089  0.017343  0.023936  0.016959
# COPOD    0.023525  0.016869  0.016845  0.017822
# ECOD     0.022585  0.016130  0.019370  0.023589
# SO_GAAL  0.023697  0.020940  0.021791  0.028831
