# %%
from source.outliers_detector_utils import *
from source.outliers_detector import OutlierGridSearcher
# Out:
# 2022-03-08 17:38:26.817752: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-03-08 17:38:26.817917: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
#*** heartFailurePrediction ***#
ogsheartFailurePrediction = OutlierGridSearcher(train_func=train_model_heart)
X_train, y_train = load_data_heartFailurePrediction()
X_filtered, y_filtered = ogsheartFailurePrediction.fit(X_train, y_train, top_nums_to_remove=[0, 5, 10])
# Out:
# testing COF
# testing OCSVM
# testing KNN
# testing MCD
# testing PCA
# testing LODA
# testing COPOD
# testing ECOD
# testing SO_GAAL
# 2022-03-08 17:38:30.656519: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2022-03-08 17:38:30.685031: E tensorflow/stream_executor/cuda/cuda_driver.cc:328] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-03-08 17:38:30.685102: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (il-eyalco-lp): /proc/driver/nvidia/version does not exist
# 2022-03-08 17:38:30.686929: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-03-08 17:38:30.808740: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2022-03-08 17:38:30.813902: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2803000000 Hz
# ### OUTPUT ###
# The best score was achieved using PCA when filtering 10 outliers
# Worst score was ('SO_GAAL', 5)
#               0         5         10
# COF      0.84823  0.842655  0.842575
# OCSVM    0.84823  0.853447  0.852832
# KNN      0.84823  0.843668  0.837544
# MCD      0.84823  0.852729  0.848379
# PCA      0.84823  0.838756  0.856323
# LODA     0.84823  0.846135  0.835634
# COPOD    0.84823  0.853700  0.842185
# ECOD     0.84823  0.847360  0.841399
# SO_GAAL  0.84823  0.830784  0.852577

# %%
#*** HeartDiseaseUCI ***#
ogsHeartDiseaseUCI = OutlierGridSearcher(train_func=train_model_heart, scoring_weights=[0.4, 0.0, 0.1, 0.5])
X_train, y_train = load_data_HeartDiseaseUCI()
X_filtered, y_filtered = ogsHeartDiseaseUCI.fit(X_train, y_train)
# Out:
# testing COF
# testing OCSVM
# testing KNN
# testing MCD
# testing PCA
# testing LODA
# testing COPOD
# testing ECOD
# testing SO_GAAL
#
#
# ### OUTPUT ###
# The best score was achieved using MCD when filtering 30 outliers
# Worst score was ('PCA', 30)
#                0         5         10        20        30
# COF      0.838809  0.836714  0.836924  0.838986  0.836723
# OCSVM    0.838809  0.841157  0.840184  0.839439  0.839898
# KNN      0.838809  0.837831  0.837763  0.836980  0.840446
# MCD      0.838809  0.838907  0.840337  0.840651  0.843791
# PCA      0.838809  0.838062  0.836966  0.837236  0.835736
# LODA     0.838809  0.842275  0.843377  0.840740  0.840660
# COPOD    0.838809  0.837820  0.836762  0.839075  0.838432
# ECOD     0.838809  0.838047  0.838832  0.839882  0.839270
# SO_GAAL  0.838809  0.843272  0.842412  0.839114  0.837808

# %%
# *** Cardiotocography ***#
ogsCardiotocography = OutlierGridSearcher(train_func=train_model_Cardiotocography)
X_train, y_train = load_data_Cardiotocography()
X_filtered, y_filtered = ogsCardiotocography.fit(X_train, y_train, top_nums_to_remove=[0, 10, 30, 50, 100, 150, 200])
# Out:
# testing COF
# testing OCSVM
# testing KNN
# testing MCD
# testing PCA
# testing LODA
# testing COPOD
# testing ECOD
# testing SO_GAAL
#
#
# ### OUTPUT ###
# The best score was achieved using COF when filtering 30 outliers
# Worst score was ('MCD', 150)
#               0         10        30        50        100       150       200
# COF      0.843972  0.836105  0.875300  0.842615  0.848635  0.834606  0.819843
# OCSVM    0.843972  0.814727  0.810552  0.794189  0.843672  0.860051  0.819843
# KNN      0.843972  0.800475  0.836930  0.871671  0.821340  0.860051  0.853786
# MCD      0.843972  0.836105  0.846523  0.842615  0.838710  0.773537  0.817232
# PCA      0.843972  0.831354  0.846523  0.840194  0.823821  0.852417  0.832898
# LODA     0.843972  0.838480  0.860911  0.823245  0.816377  0.832061  0.809399
# COPOD    0.843972  0.845606  0.808153  0.828087  0.861042  0.826972  0.838120
# ECOD     0.843972  0.838480  0.827338  0.837772  0.853598  0.809160  0.822454
# SO_GAAL  0.843972  0.833729  0.851319  0.852300  0.861042  0.806616  0.843342

# %%
#*** HousePrices ***#
ogsHousePrices = OutlierGridSearcher(train_model_house, higher_is_better=False)
X_train, y_train = load_data_house()
X_filtered, y_filtered = ogsHousePrices.fit(X_train, y_train, top_nums_to_remove=[0, 10, 20, 30])
# Out:
# testing COF
# testing OCSVM
# testing KNN
# testing MCD
# testing PCA
# testing LODA
# testing COPOD
# testing ECOD
# testing SO_GAAL
#
#
# ### OUTPUT ###
# The best score was achieved using COF when filtering 30 outliers
# Worst score was ('MCD', 30)
#                0         10        20        30
# COF      0.023315  0.019835  0.015606  0.013052
# OCSVM    0.023315  0.023572  0.045769  0.020941
# KNN      0.023315  0.016113  0.022091  0.017347
# MCD      0.023315  0.045839  0.020567  0.050128
# PCA      0.023315  0.018304  0.019131  0.019193
# LODA     0.023315  0.017818  0.015990  0.015047
# COPOD    0.023315  0.016868  0.016780  0.020486
# ECOD     0.023315  0.016503  0.019362  0.021780
# SO_GAAL  0.023315  0.020940  0.021791  0.028831
