# %%
from source.outlier_grid_searcher_utils import *
from source.outliers_detector import OutlierGridSearcher
# Out:
# 2022-03-04 15:59:52.337235: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-03-04 15:59:52.337287: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
#*** heartFailurePrediction ***#
ogsheartFailurePrediction = OutlierGridSearcher(train_func=train_model_heart)
X_train, y_train = load_data_heartFailurePrediction()
X_filtered, y_filtered = ogsheartFailurePrediction.fit(X_train, y_train, top_nums_to_remove=[0, 5, 10])
# Out:
# testing COF
# testing OCSVM
# testing KNN
# testing MCD
# testing PCA
# testing LODA
# testing COPOD
# testing ECOD
# testing SO_GAAL
# 2022-03-04 15:59:54.807606: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2022-03-04 15:59:54.820064: E tensorflow/stream_executor/cuda/cuda_driver.cc:328] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-03-04 15:59:54.820112: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (il-eyalco-lp): /proc/driver/nvidia/version does not exist
# 2022-03-04 15:59:54.820620: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-03-04 15:59:54.895468: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2022-03-04 15:59:54.896100: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2803000000 Hz
# ### OUTPUT ###
# The best score was achieved using PCA when filtering 10 outliers
#                0         5         10
# COF      0.848230  0.842655  0.842575
# OCSVM    0.848713  0.853447  0.852832
# KNN      0.848713  0.843668  0.837544
# MCD      0.851582  0.844343  0.848914
# PCA      0.851295  0.842865  0.856323
# LODA     0.848448  0.847298  0.829588
# COPOD    0.844653  0.843933  0.847280
# ECOD     0.851554  0.846803  0.845643
# SO_GAAL  0.851582  0.844524  0.847043
# testing COF
# testing OCSVM
# testing KNN
# testing MCD
# testing PCA
# testing LODA
# testing COPOD
# testing ECOD
# testing SO_GAAL
#
#
# ### OUTPUT ###
# The best score was achieved using PCA when filtering 30 outliers
#                0         5         10        20        30
# COF      0.838809  0.836714  0.836924  0.838986  0.836723
# OCSVM    0.842012  0.841157  0.840184  0.839439  0.839898
# KNN      0.838664  0.837831  0.837763  0.836980  0.840446
# MCD      0.837751  0.839914  0.840624  0.843614  0.842681
# PCA      0.838015  0.838909  0.845037  0.846144  0.850226
# LODA     0.834982  0.838110  0.838867  0.837586  0.837469
# COPOD    0.836834  0.837940  0.842260  0.837308  0.839598
# ECOD     0.836875  0.837896  0.837862  0.839082  0.835141
# SO_GAAL  0.836869  0.838197  0.838123  0.836289  0.837658
# testing COF
# testing OCSVM
# testing KNN
# testing MCD
# testing PCA
# testing LODA
# testing COPOD
# testing ECOD
# testing SO_GAAL
#
#
# ### OUTPUT ###
# The best score was achieved using SO_GAAL when filtering 100 outliers
#               0         10        30        50        100       150       200
# COF      0.843972  0.836105  0.875300  0.842615  0.848635  0.834606  0.819843
# OCSVM    0.843972  0.814727  0.810552  0.794189  0.843672  0.860051  0.819843
# KNN      0.843972  0.800475  0.836930  0.871671  0.821340  0.860051  0.853786
# MCD      0.841608  0.836105  0.793765  0.842615  0.838710  0.786260  0.809399
# PCA      0.843972  0.831354  0.846523  0.840194  0.823821  0.852417  0.832898
# LODA     0.843972  0.833729  0.846523  0.832930  0.831266  0.839695  0.827676
# COPOD    0.843972  0.845606  0.834532  0.832930  0.836228  0.821883  0.845953
# ECOD     0.841608  0.838480  0.827338  0.830508  0.846154  0.832061  0.835509
# SO_GAAL  0.836879  0.805226  0.851319  0.820823  0.880893  0.798982  0.853786
# testing COF
# testing OCSVM
# testing KNN
# testing MCD
# testing PCA
# testing LODA
# testing COPOD
# testing ECOD
# testing SO_GAAL
#
#
# ### OUTPUT ###
# The best score was achieved using COF when filtering 30 outliers
#                0         10        20        30
# COF      0.023315  0.019835  0.015606  0.013052
# OCSVM    0.023708  0.023572  0.045769  0.020941
# KNN      0.023262  0.016113  0.022091  0.017347
# MCD      0.023089  0.018239  0.031086  0.019747
# PCA      0.022821  0.018433  0.014252  0.016152
# LODA     0.023253  0.019800  0.023641  0.019210
# COPOD    0.023438  0.016839  0.016783  0.020917
# ECOD     0.022566  0.016493  0.019349  0.023935
# SO_GAAL  0.023697  0.020940  0.021791  0.028831
# testing COF
# testing OCSVM
# testing KNN
# testing MCD
# testing PCA
# testing LODA
# testing COPOD
# testing ECOD
# testing SO_GAAL
#
#
# ### OUTPUT ###
# The best score was achieved using SO_GAAL when filtering 5 outliers
#                0         5         10
# COF      0.848230  0.842655  0.842575
# OCSVM    0.848713  0.853447  0.852832
# KNN      0.848713  0.843668  0.837544
# MCD      0.851582  0.841495  0.839809
# PCA      0.851295  0.838756  0.856323
# LODA     0.852025  0.838861  0.841142
# COPOD    0.851582  0.850888  0.841077
# ECOD     0.854999  0.850818  0.845060
# SO_GAAL  0.850136  0.856709  0.832290
# testing COF
# testing OCSVM
# testing KNN
# testing MCD
# testing PCA
# testing LODA
# testing COPOD
# testing ECOD
# testing SO_GAAL
#
#
# ### OUTPUT ###
# The best score was achieved using PCA when filtering 20 outliers
#                0         5         10        20        30
# COF      0.838809  0.836714  0.836924  0.838986  0.836723
# OCSVM    0.842012  0.841157  0.840184  0.839439  0.839898
# KNN      0.838664  0.837831  0.837763  0.836980  0.840446
# MCD      0.836756  0.838863  0.836608  0.835678  0.838879
# PCA      0.835890  0.841116  0.843999  0.847245  0.846657
# LODA     0.836081  0.834903  0.833553  0.833201  0.832614
# COPOD    0.835899  0.837804  0.836304  0.838409  0.838089
# ECOD     0.835953  0.836968  0.835996  0.838063  0.832888
# SO_GAAL  0.836869  0.837104  0.836042  0.835218  0.836750
# testing COF
# testing OCSVM
# testing KNN
# testing MCD
# testing PCA
# testing LODA
# testing COPOD
# testing ECOD
# testing SO_GAAL
#
#
# ### OUTPUT ###
# The best score was achieved using COF when filtering 30 outliers
#               0         10        30        50        100       150       200
# COF      0.843972  0.836105  0.875300  0.842615  0.848635  0.834606  0.819843
# OCSVM    0.843972  0.814727  0.810552  0.794189  0.843672  0.860051  0.819843
# KNN      0.843972  0.800475  0.836930  0.871671  0.821340  0.860051  0.853786
# MCD      0.843972  0.836105  0.796163  0.832930  0.848635  0.796438  0.814621
# PCA      0.843972  0.831354  0.846523  0.840194  0.823821  0.852417  0.832898
# LODA     0.843972  0.845606  0.827338  0.842615  0.836228  0.839695  0.830287
# COPOD    0.843972  0.845606  0.820144  0.820823  0.816377  0.865140  0.832898
# ECOD     0.841608  0.840855  0.827338  0.837772  0.846154  0.806616  0.827676
# SO_GAAL  0.839243  0.831354  0.832134  0.832930  0.833747  0.806616  0.851175
# testing COF
# testing OCSVM
# testing KNN
# testing MCD
# testing PCA
# testing LODA
# testing COPOD
# testing ECOD
# testing SO_GAAL

# %%
#*** HeartDiseaseUCI ***#
ogsHeartDiseaseUCI = OutlierGridSearcher(train_func=train_model_heart, scoring_weights=[0.4, 0.0, 0.1, 0.5])
X_train, y_train = load_data_HeartDiseaseUCI()
X_filtered, y_filtered = ogsHeartDiseaseUCI.fit(X_train, y_train)

# %%
# *** Cardiotocography ***#
ogsCardiotocography = OutlierGridSearcher(train_func=train_model_Cardiotocography)
X_train, y_train = load_data_Cardiotocography()
X_filtered, y_filtered = ogsCardiotocography.fit(X_train, y_train, top_nums_to_remove=[0, 10, 30, 50, 100, 150, 200])

# %%
#*** HousePrices ***#
ogsHousePrices = OutlierGridSearcher(train_model_house, higher_is_better=False)
X_train, y_train = load_data_house()
X_filtered, y_filtered = ogsHousePrices.fit(X_train, y_train, top_nums_to_remove=[0, 10, 20, 30])
